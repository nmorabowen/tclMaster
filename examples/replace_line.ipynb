# %%
from tclMaster import tclMaster, batch_replace
from pathlib import Path

# %%
model_path = Path(r'C:\Users\nmb\Desktop\DRM_ElementSize\10000')

model=tclMaster(model_path=model_path)
filename=r'analysis_steps.tcl'

old_path = "/home/nmb/Dropbox/UANDES EC/San Ramon v3/motions/m6.7_rup_bl_1_motions_sta_2.h5drm"
new_path = "/mnt/krakenschest/home/FSR_DRM_Motions/m6.7_rup_bl_1_motions_sta_2.h5drm"

model.tcl_preprocessor.replace_string_content(
    filename=filename,
    old_string=old_path,
    new_string=new_path
)

# %%
root_path = Path(r'C:\Users\nmb\Desktop\DRM_ElementSize')

batch_replace(
    root_paths=root_path,
    target_filename=filename,
    old_str=old_path,
    new_str=new_path
)
# Out:
# --- Starting Batch Replacement in: C:\Users\nmb\Desktop\DRM_ElementSize ---
# Found 5 models to process in DRM_ElementSize.
#
# [Updated] 10000: 1 replacement(s)
# [Updated] 12500: 1 replacement(s)
# [Updated] 2500: 1 replacement(s)
# [Updated] 5000: 1 replacement(s)
# [Updated] 7500: 1 replacement(s)
# --- Finished DRM_ElementSize. Replacements: 5 ---
#
# === GLOBAL COMPLETE. Total replacements made: 5 ===

# %%
root_path = Path(r'C:\Users\nmb\Desktop\DRM_ElementSize')

batch_replace(
    root_paths=root_path,
    target_filename=filename,
    old_str=old_path,
    new_str=new_path
)
# Out:
# --- Starting Batch Replacement in: C:\Users\nmb\Desktop\DRM_ElementSize ---
# Found 5 models to process in DRM_ElementSize.
#
# [Updated] 10000: 1 replacement(s)
# [Updated] 12500: 1 replacement(s)
# [Updated] 2500: 1 replacement(s)
# [Updated] 5000: 1 replacement(s)
# [Updated] 7500: 1 replacement(s)
# --- Finished DRM_ElementSize. Replacements: 5 ---
#
# === GLOBAL COMPLETE. Total replacements made: 5 ===

# %%
root_path_list = [Path(r'C:\Users\nmb\Desktop\DRM_ElementSize'),
                  Path(r'C:\Users\nmb\Desktop\DRM_ElementType')]

batch_replace(
    root_paths=root_path_list,
    target_filename=filename,
    old_str=old_path,
    new_str=new_path
)

# %%
root_path_list = [Path(r'C:\Users\nmb\Desktop\4A_ElementSize'),]

batch_replace(
    root_paths=root_path_list,
    target_filename=filename,
    old_str=old_path,
    new_str=new_path
)
# Out:
# --- Starting Batch Replacement in: C:\Users\nmb\Desktop\4A_ElementSize ---
# Found 5 models to process in 4A_ElementSize.
#
# [Skipped] 10000: String not found.
# [Skipped] 12500: String not found.
# [Skipped] 2500: String not found.
# [Skipped] 5000: String not found.
# [Skipped] 7500: String not found.
# --- Finished 4A_ElementSize. Replacements: 0 ---
#
# === GLOBAL COMPLETE. Total replacements made: 0 ===
